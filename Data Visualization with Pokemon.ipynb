# %% [markdown]
# # Data Visualization with Pokemon

# %% [markdown]
# ## Introduction

# %% [markdown]
# This is my first project using Python, Pandas, and Matplotlib. The goal of this project is to refine my data analysis skills and improve along the way. Recurring updates may happen to this notebook due to me testing out new information.

# %% [markdown]
# ## Imports and Reading CSV

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('pokemon.csv')

# %% [markdown]
# ## CSV Display

# %%
data
# Out:
#       Id                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ## Section 1: Comparing Generations

# %% [markdown]
# To get started, I wanted to compare two generations of Pokemon, Generation 1 and Generation 6. By using the "Generation" column of the dataset, I can separate the two generations with the variables "genOne" and "genSix".

# %%
genOne = data[data.Generation == 1]
genSix = data[data.Generation == 6]

# %%
genOne
# Out:
#       Id                   Name   Type 1    Type 2  Total   HP  Attack  \
# 0      1              Bulbasaur    Grass    Poison    318   45      49
# 1      2                Ivysaur    Grass    Poison    405   60      62
# 2      3               Venusaur    Grass    Poison    525   80      82
# 3      3  VenusaurMega Venusaur    Grass    Poison    625   80     100
# 4      4             Charmander     Fire       NaN    309   39      52
# ..   ...                    ...      ...       ...    ...  ...     ...
# 161  149              Dragonite   Dragon    Flying    600   91     134
# 162  150                 Mewtwo  Psychic       NaN    680  106     110
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 165  151                    Mew  Psychic       NaN    600  100     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
genSix
# Out:
#       Id                 Name   Type 1    Type 2  Total  HP  Attack  Defense  \
# 718  650              Chespin    Grass       NaN    313  56      61       65
# 719  651            Quilladin    Grass       NaN    405  61      78       95
# 720  652           Chesnaught    Grass  Fighting    530  88     107      122
# 721  653             Fennekin     Fire       NaN    307  40      45       40
# 722  654              Braixen     Fire       NaN    409  59      59       58
# ..   ...                  ...      ...       ...    ...  ..     ...      ...
# 795  719              Diancie     Rock     Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock     Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic     Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic      Dark    680  80     160       60
# 799  721            Volcanion     Fire     Water    600  80     110      120
#
# ...

# %% [markdown]
# Now, I'm using plt.plot to plot all of the Pokemon by their Id numbers (x-axis) and their Total (y-axis), which are the products of the Pokemon's base values.

# %%
plt.plot(genOne.Id, genOne.Total)
plt.plot(genSix.Id - 649, genSix.Total)
plt.legend(['Gen 1', 'Gen 6'])
plt.xlabel('Id Number (from original game)')
plt.ylabel('Total Base Value')
plt.show()

# %% [markdown]
# From the chart shown above, we can conclude that:
#
# . The total base values gradually increase the higher the id number is, indicating that the higher the id number, the stronger the pokemon
#
# . There are about half as many pokemon created from the sixth generation than the first one
